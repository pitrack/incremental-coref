# %%
import csv
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
sns.set_style("dark")

# %%
a = open("memory_data_coref.tsv", 'r')
reader = csv.reader(a, delimiter="\t")

# %%
data = list(reader)

# %%
data
# Out:
# [['2313', '3.50651845', 'joshi_base'],
#  ['2221', '3.343008392', 'joshi_base'],
#  ['1924', '2.914180126', 'joshi_base'],
#  ['1895', '2.932690699', 'joshi_base'],
#  ['1718', '2.605750114', 'joshi_base'],
#  ['1649', '2.460671097', 'joshi_base'],
#  ['1506', '2.30333123', 'joshi_base'],
#  ['1433', '2.173757222', 'joshi_base'],
#  ['1297', '2.010247163', 'joshi_base'],
#  ['1295', '2.149076458', 'joshi_base'],
#  ['1288', '1.988651495', 'joshi_base'],
#  ['1281', '2.010247163', 'joshi_base'],
#  ['1145', '1.664716475', 'joshi_base'],
#  ['1144', '1.738758765', 'joshi_base'],
#  ['1125', '1.66780157', 'joshi_base'],
#  ['1120', '1.572163612', 'joshi_base'],
#  ['1102', '1.66780157', 'joshi_base'],
#  ['1092', '1.738758765', 'joshi_base'],
#  ['1092', '1.680141952', 'joshi_base'],
#  ['1079', '1.652376093', 'joshi_base'],
#  ['1077', '1.754184242', 'joshi_base'],
#  ['1066', '1.535142466', 'joshi_base'],
#  ['1040', '1.581418898', 'joshi_base'],
#  ['1019', '1.584503993', 'joshi_base'],
#  ['1019', '1.476525653', 'joshi_base'],
#  ['1017', '1.507376608', 'joshi_base'],
#  ['1014', '1.673971761', 'joshi_base'],
#  ['1007', '1.763439529', 'joshi_base'],
#  ['1005', '1.612269852', 'joshi_base'],
#  ['1003', '1.532057371', 'joshi_base'],
#  ['994', '1.562908325', 'joshi_base'],
#  ['989', '1.470355462', 'joshi_base'],
#  ['988', '1.52588718', 'joshi_base'],
#  ['987', '1.618440043', 'joshi_base'],
#  ['984', '1.430249222', 'joshi_base'],
#  ['978', '1.556738134', 'joshi_base'],
#  ['977', '1.427164126', 'joshi_base'],
#  ['976', '1.454929985', 'joshi_base'],
#  ['964', '1.387057886', 'joshi_base'],
#  ['961', '1.414823744', 'joshi_base'],
#  ['947', '1.390142981', 'joshi_base'],
#  ['945', '1.420993935', 'joshi_base'],
#  ['921', '1.461100176', 'joshi_base'],
#  ['920', '1.368547313', 'joshi_base'],
#  ['905', '1.461100176', 'joshi_base'],
#  ['902', '1.420993935', 'joshi_base'],
#  ['897', '1.396313172', 'joshi_base'],
#  ['876', '1.3099305', 'joshi_base'],
#  ['860', '1.3099305', 'joshi_base'],
#  ['856', '1.254398782', 'joshi_base'],
#  ['855', '1.380887695', 'joshi_base'],
#  ['852', '1.291419927', 'joshi_base'],
#  ['851', '1.2420584', 'joshi_base'],
#  ['845', '1.303760309', 'joshi_base'],
#  ['838', '1.27599445', 'joshi_base'],
#  ['824', '1.3099305', 'joshi_base'],
#  ['807', '1.260568973', 'joshi_base'],
#  ['802', '1.177271396', 'joshi_base'],
#  ['798', '1.254398782', 'joshi_base'],
#  ['798', '1.235888209', 'joshi_base'],
#  ['793', '1.16801611', 'joshi_base'],
#  ['786', '1.201952159', 'joshi_base'],
#  ['783', '1.149505537', 'joshi_base'],
#  ['772', '1.180356491', 'joshi_base'],
#  ['766', '1.13408006', 'joshi_base'],
#  ['759', '1.143335346', 'joshi_base'],
#  ['753', '1.217377637', 'joshi_base'],
#  ['751', '1.359292027', 'joshi_base'],
#  ['743', '1.16801611', 'joshi_base'],
#  ['731', '1.124824774', 'joshi_base'],
#  ['729', '1.152590632', 'joshi_base'],
#  ['728', '1.097058915', 'joshi_base'],
#  ['724', '1.20812235', 'joshi_base'],
#  ['717', '1.180356491', 'joshi_base'],
#  ['716', '1.063122865', 'joshi_base'],
#  ['714', '1.140250251', 'joshi_base'],
#  ['708', '1.093973819', 'joshi_base'],
#  ['705', '1.081633437', 'joshi_base'],
#  ['704', '1.060037769', 'joshi_base'],
#  ['703', '1.121739678', 'joshi_base'],
#  ['695', '1.075463247', 'joshi_base'],
#  ['695', '1.044612292', 'joshi_base'],
#  ['691', '1.118654583', 'joshi_base'],
#  ['688', '1.10014401', 'joshi_base'],
#  ['685', '1.019931529', 'joshi_base'],
#  ['658', '1.056952674', 'joshi_base'],
#  ['656', '0.9890805744', 'joshi_base'],
#  ['654', '1.056952674', 'joshi_base'],
#  ['651', '1.013761338', 'joshi_base'],
#  ['645', '1.035357006', 'joshi_base'],
#  ['643', '0.9921656698', 'joshi_base'],
#  ['641', '0.9767401926', 'joshi_base'],
#  ['640', '0.9643998109', 'joshi_base'],
#  ['638', '1.047697388', 'joshi_base'],
#  ['636', '1.112484392', 'joshi_base'],
#  ['628', '1.013761338', 'joshi_base'],
#  ['625', '0.9890805744', 'joshi_base'],
#  ['623', '0.9890805744', 'joshi_base'],
#  ['622', '1.023016624', 'joshi_base'],
#  ['622', '0.9150382839', 'joshi_base'],
#  ['617', '0.9489743337', 'joshi_base'],
#  ['617', '0.9335488565', 'joshi_base'],
#  ['610', '1.072378151', 'joshi_base'],
#  ['605', '0.9767401926', 'joshi_base'],
#  ['603', '0.9643998109', 'joshi_base'],
#  ['603', '0.9150382839', 'joshi_base'],
#  ['593', '0.936633952', 'joshi_base'],
#  ['592', '0.9057829976', 'joshi_base'],
#  ['590', '0.9859954789', 'joshi_base'],
#  ['583', '0.9397190474', 'joshi_base'],
#  ['581', '0.9212084748', 'joshi_base'],
#  ['579', '0.9273786657', 'joshi_base'],
#  ['578', '0.8903575204', 'joshi_base'],
#  ['576', '0.9057829976', 'joshi_base'],
#  ['574', '0.9458892383', 'joshi_base'],
#  ['573', '0.9273786657', 'joshi_base'],
#  ['571', '0.8625916615', 'joshi_base'],
#  ['570', '0.8996128067', 'joshi_base'],
#  ['569', '0.8718469478', 'joshi_base'],
#  ['567', '0.9551445246', 'joshi_base'],
#  ['567', '0.8656767569', 'joshi_base'],
#  ['566', '0.887272425', 'joshi_base'],
#  ['565', '0.8811022341', 'joshi_base'],
#  ['558', '0.8471661843', 'joshi_base'],
#  ['555', '0.9057829976', 'joshi_base'],
#  ['548', '0.8656767569', 'joshi_base'],
#  ['547', '0.8564214706', 'joshi_base'],
#  ['546', '0.8625916615', 'joshi_base'],
#  ['546', '0.8348258026', 'joshi_base'],
#  ['541', '0.9613147154', 'joshi_base'],
#  ['538', '0.8595065661', 'joshi_base'],
#  ['521', '0.8625916615', 'joshi_base'],
#  ['519', '0.8533363752', 'joshi_base'],
#  ['516', '0.8749320433', 'joshi_base'],
#  ['516', '0.8101450391', 'joshi_base'],
#  ['512', '0.7731238939', 'joshi_base'],
#  ['511', '0.7947195619', 'joshi_base'],
#  ['510', '0.81631523', 'joshi_base'],
#  ['499', '0.7978046574', 'joshi_base'],
#  ['489', '0.8039748482', 'joshi_base'],
#  ['488', '0.766953703', 'joshi_base'],
#  ['487', '0.7978046574', 'joshi_base'],
#  ['486', '0.7700387985', 'joshi_base'],
#  ['482', '0.7792940848', 'joshi_base'],
#  ['482', '0.7515282258', 'joshi_base'],
#  ['471', '0.7762089893', 'joshi_base'],
#  ['471', '0.7700387985', 'joshi_base'],
#  ['468', '0.8409959935', 'joshi_base'],
#  ['466', '0.7916344665', 'joshi_base'],
#  ['463', '0.7731238939', 'joshi_base'],
#  ['454', '0.7515282258', 'joshi_base'],
#  ['453', '0.7854642756', 'joshi_base'],
#  ['452', '0.7206772715', 'joshi_base'],
#  ['450', '0.7237623669', 'joshi_base'],
#  ['447', '0.766953703', 'joshi_base'],
#  ['439', '0.717592176', 'joshi_base'],
#  ['439', '0.6990816034', 'joshi_base'],
#  ['431', '0.7515282258', 'joshi_base'],
#  ['422', '0.717592176', 'joshi_base'],
#  ['422', '0.6805710308', 'joshi_base'],
#  ['422', '0.6589753628', 'joshi_base'],
#  ['420', '0.7422729395', 'joshi_base'],
#  ['418', '0.7361027487', 'joshi_base'],
#  ['417', '0.7206772715', 'joshi_base'],
#  ['415', '0.6836561263', 'joshi_base'],
#  ['415', '0.6651455536', 'joshi_base'],
#  ['409', '0.7114219852', 'joshi_base'],
#  ['407', '0.6836561263', 'joshi_base'],
#  ['406', '0.6898263171', 'joshi_base'],
#  ['403', '0.6929114126', 'joshi_base'],
#  ['402', '0.6620604582', 'joshi_base'],
#  ['401', '0.7052517943', 'joshi_base'],
#  ['394', '0.67440084', 'joshi_base'],
#  ['391', '0.6589753628', 'joshi_base'],
#  ['385', '0.6497124545', 'joshi_base'],
#  ['379', '0.6497124359', 'joshi_base'],
#  ['372', '0.6497124061', 'joshi_base'],
#  ['371', '0.6497124285', 'joshi_base'],
#  ['369', '0.6497123204', 'joshi_base'],
#  ['368', '0.6497122496', 'joshi_base'],
#  ['366', '0.6713157445', 'joshi_base'],
#  ['364', '0.7607835121', 'joshi_base'],
#  ['363', '0.6497123316', 'joshi_base'],
#  ['361', '0.649712503', 'joshi_base'],
#  ['361', '0.6497123428', 'joshi_base'],
#  ['357', '0.6497121677', 'joshi_base'],
#  ['353', '0.6497121155', 'joshi_base'],
#  ['351', '0.6497123316', 'joshi_base'],
#  ['347', '0.6497122683', 'joshi_base'],
#  ['345', '0.6497122571', 'joshi_base'],
#  ['342', '0.6497122422', 'joshi_base'],
#  ['341', '0.6497123614', 'joshi_base'],
#  ['339', '0.6497121379', 'joshi_base'],
#  ['333', '0.6497120783', 'joshi_base'],
#  ['332', '0.6497122869', 'joshi_base'],
#  ['331', '0.6497121379', 'joshi_base'],
#  ['325', '0.6497121118', 'joshi_base'],
#  ['323', '0.6497120336', 'joshi_base'],
#  ['322', '0.6497122385', 'joshi_base'],
#  ['322', '0.649712082', 'joshi_base'],
#  ['322', '0.6497120187', 'joshi_base'],
#  ['320', '0.6497121789', 'joshi_base'],
#  ['311', '0.6497121044', 'joshi_base'],
#  ['311', '0.6497118883', 'joshi_base'],
#  ['310', '0.6497121081', 'joshi_base'],
#  ['305', '0.6497120447', 'joshi_base'],
#  ['304', '0.6497119591', 'joshi_base'],
#  ['302', '0.6497119665', 'joshi_base'],
#  ['291', '0.6497118101', 'joshi_base'],
#  ['286', '0.6497117393', 'joshi_base'],
#  ['284', '0.6497118175', 'joshi_base'],
#  ['276', '0.6497117244', 'joshi_base'],
#  ['259', '0.6497115493', 'joshi_base'],
#  ['254', '0.649711363', 'joshi_base'],
#  ['251', '0.6497113332', 'joshi_base'],
#  ['250', '0.6497116163', 'joshi_base'],
#  ['246', '0.6497113779', 'joshi_base'],
#  ['244', '0.6497115009', 'joshi_base'],
#  ['244', '0.6497112662', 'joshi_base'],
#  ['242', '0.6497112624', 'joshi_base'],
#  ['241', '0.6497116312', 'joshi_base'],
#  ['241', '0.6497113034', 'joshi_base'],
#  ['237', '0.6497113556', 'joshi_base'],
#  ['234', '0.649711553', 'joshi_base'],
#  ['234', '0.649711296', 'joshi_base'],
#  ['234', '0.649711214', 'joshi_base'],
#  ['230', '0.6497112438', 'joshi_base'],
#  ['227', '0.6497112736', 'joshi_base'],
#  ['226', '0.6497111768', 'joshi_base'],
#  ['222', '0.6497111917', 'joshi_base'],
#  ['222', '0.6497111544', 'joshi_base'],
#  ['221', '0.6497111619', 'joshi_base'],
#  ['218', '0.6497112103', 'joshi_base'],
#  ['213', '0.6497113109', 'joshi_base'],
#  ['213', '0.649711296', 'joshi_base'],
#  ['213', '0.6497112699', 'joshi_base'],
#  ['210', '0.649711173', 'joshi_base'],
#  ['210', '0.6497111395', 'joshi_base'],
#  ['209', '0.6497113854', 'joshi_base'],
#  ['208', '0.649711132', 'joshi_base'],
#  ['206', '0.649711106', 'joshi_base'],
#  ['205', '0.6497111395', 'joshi_base'],
#  ['199', '0.6497111581', 'joshi_base'],
#  ['199', '0.6497110128', 'joshi_base'],
#  ['198', '0.649710957', 'joshi_base'],
#  ['197', '0.6497110054', 'joshi_base'],
#  ['194', '0.6497113109', 'joshi_base'],
#  ['193', '0.6497109681', 'joshi_base'],
#  ['192', '0.6497109644', 'joshi_base'],
#  ['191', '0.6497110762', 'joshi_base'],
#  ['188', '0.6497111395', 'joshi_base'],
#  ['188', '0.6497111358', 'joshi_base'],
#  ['186', '0.6497110948', 'joshi_base'],
#  ['186', '0.6497110277', 'joshi_base'],
#  ['180', '0.649710834', 'joshi_base'],
#  ['178', '0.6497109979', 'joshi_base'],
#  ['178', '0.6497108825', 'joshi_base'],
#  ['178', '0.6497108713', 'joshi_base'],
#  ['176', '0.6497108974', 'joshi_base'],
#  ['174', '0.6497108564', 'joshi_base'],
#  ['173', '0.6497108154', 'joshi_base'],
#  ['169', '0.6497107446', 'joshi_base'],
#  ['168', '0.6497108452', 'joshi_base'],
#  ['167', '0.6497108117', 'joshi_base'],
#  ['167', '0.6497108005', 'joshi_base'],
#  ['166', '0.6497108191', 'joshi_base'],
#  ['166', '0.6497108117', 'joshi_base'],
#  ['164', '0.6497106925', 'joshi_base'],
#  ['163', '0.6497108676', 'joshi_base'],
#  ['162', '0.6497108266', 'joshi_base'],
#  ['162', '0.6497106589', 'joshi_base'],
#  ['156', '0.6497107968', 'joshi_base'],
#  ['155', '0.6497107223', 'joshi_base'],
#  ['153', '0.6497106776', 'joshi_base'],
#  ['153', '0.6497106701', 'joshi_base'],
#  ['152', '0.6497106329', 'joshi_base'],
#  ['150', '0.6497105733', 'joshi_base'],
#  ['146', '0.6497106105', 'joshi_base'],
#  ['145', '0.6497105658', 'joshi_base'],
#  ['143', '0.6497105472', 'joshi_base'],
#  ['141', '0.6497105062', 'joshi_base'],
#  ['140', '0.6497106925', 'joshi_base'],
#  ['139', '0.6497105844', 'joshi_base'],
#  ['138', '0.6497106478', 'joshi_base'],
#  ['130', '0.6497104429', 'joshi_base'],
#  ['129', '0.6497103944', 'joshi_base'],
#  ['128', '0.6497104093', 'joshi_base'],
#  ['124', '0.6497104615', 'joshi_base'],
#  ['123', '0.6497103684', 'joshi_base'],
#  ['123', '0.6497103311', 'joshi_base'],
#  ['118', '0.6497103795', 'joshi_base'],
#  ['115', '0.6497103125', 'joshi_base'],
#  ['113', '0.6497102901', 'joshi_base'],
#  ['111', '0.6497103311', 'joshi_base'],
#  ['110', '0.6497102641', 'joshi_base'],
#  ['110', '0.6497102305', 'joshi_base'],
#  ['108', '0.6497103684', 'joshi_base'],
#  ['107', '0.6497103386', 'joshi_base'],
#  ['107', '0.6497102529', 'joshi_base'],
#  ['99', '0.6497101746', 'joshi_base'],
#  ['97', '0.6497101896', 'joshi_base'],
#  ['96', '0.6497102082', 'joshi_base'],
#  ['96', '0.649710156', 'joshi_base'],
#  ['94', '0.6497101858', 'joshi_base'],
#  ['94', '0.6497101039', 'joshi_base'],
#  ['93', '0.6497101784', 'joshi_base'],
#  ['91', '0.6497102268', 'joshi_base'],
#  ['90', '0.6497101299', 'joshi_base'],
#  ['87', '0.6497101001', 'joshi_base'],
#  ['85', '0.6497100741', 'joshi_base'],
#  ['85', '0.649710048', 'joshi_base'],
#  ['83', '0.6497100443', 'joshi_base'],
#  ['82', '0.6497101039', 'joshi_base'],
#  ['82', '0.6497100517', 'joshi_base'],
#  ['81', '0.6497100852', 'joshi_base'],
#  ['77', '0.6497100405', 'joshi_base'],
#  ['76', '0.6497099809', 'joshi_base'],
#  ['74', '0.6497099623', 'joshi_base'],
#  ['73', '0.6497099511', 'joshi_base'],
#  ['73', '0.64970994', 'joshi_base'],
#  ['73', '0.6497099288', 'joshi_base'],
#  ['72', '0.6497099251', 'joshi_base'],
#  ['68', '0.6497099884', 'joshi_base'],
#  ['67', '0.6497100294', 'joshi_base'],
#  ['66', '0.6497099102', 'joshi_base'],
#  ['66', '0.6497099064', 'joshi_base'],
#  ['62', '0.6497099362', 'joshi_base'],
#  ['62', '0.6497098878', 'joshi_base'],
#  ['62', '0.6497098766', 'joshi_base'],
#  ['61', '0.6497099213', 'joshi_base'],
#  ['61', '0.649709858', 'joshi_base'],
#  ['60', '0.6497099027', 'joshi_base'],
#  ['58', '0.6497099251', 'joshi_base'],
#  ['57', '0.6497098617', 'joshi_base'],
#  ['56', '0.6497098133', 'joshi_base'],
#  ['54', '0.6497098133', 'joshi_base'],
#  ['45', '0.64970975', 'joshi_base'],
#  ['40', '0.6497096941', 'joshi_base'],
#  ['35', '0.6497096755', 'joshi_base'],
#  ['35', '0.6497096568', 'joshi_base'],
#  ['33', '0.6497096755', 'joshi_base'],
#  ['33', '0.6497096531', 'joshi_base'],
#  ['32', '0.6497096531', 'joshi_base'],
#  ['2313', '4.726325501', 'joshi_large'],
#  ['2221', '4.505348023', 'joshi_large'],
#  ['1924', '3.932443451', 'joshi_large'],
#  ['1895', '3.952904329', 'joshi_large'],
#  ['1718', '3.519133724', 'joshi_large'],
#  ['1649', '3.318617124', 'joshi_large'],
#  ['1506', '3.109916173', 'joshi_large'],
#  ['1433', '2.933952626', 'joshi_large'],
#  ['1297', '2.717067324', 'joshi_large'],
#  ['1295', '2.901215222', 'joshi_large'],
#  ['1288', '2.68432992', 'joshi_large'],
#  ['1281', '2.717067324', 'joshi_large'],
#  ['1145', '2.250559315', 'joshi_large'],
#  ['1144', '2.348771527', 'joshi_large'],
#  ['1125', '2.254651491', 'joshi_large'],
#  ['1120', '2.123701874', 'joshi_large'],
#  ['1102', '2.254651491', 'joshi_large'],
#  ['1092', '2.352863703', 'joshi_large'],
#  ['1092', '2.271020193', 'joshi_large'],
#  ['1079', '2.234190613', 'joshi_large'],
#  ['1077', '2.37332458', 'joshi_large'],
#  ['1066', '2.074595768', 'joshi_large'],
#  ['1040', '2.140070576', 'joshi_large'],
#  ['1019', '2.144162752', 'joshi_large'],
#  ['1019', '2.000936609', 'joshi_large'],
#  ['1017', '2.041858364', 'joshi_large'],
#  ['1014', '2.262835842', 'joshi_large'],
#  ['1007', '2.385601107', 'joshi_large'],
#  ['1005', '2.180992331', 'joshi_large'],
#  ['1003', '2.070503592', 'joshi_large'],
#  ['994', '2.115517523', 'joshi_large'],
#  ['989', '1.992752258', 'joshi_large'],
#  ['988', '2.062319241', 'joshi_large'],
#  ['987', '2.189176682', 'joshi_large'],
#  ['984', '1.939553976', 'joshi_large'],
#  ['978', '2.099148821', 'joshi_large'],
#  ['977', '1.931369625', 'joshi_large'],
#  ['976', '1.968199205', 'joshi_large'],
#  ['964', '1.878171343', 'joshi_large'],
#  ['961', '1.919093098', 'joshi_large'],
#  ['947', '1.878171343', 'joshi_large'],
#  ['945', '1.92727745', 'joshi_large'],
#  ['921', '1.980475731', 'joshi_large'],
#  ['920', '1.85361829', 'joshi_large'],
#  ['905', '1.976383556', 'joshi_large'],
#  ['902', '1.923185274', 'joshi_large'],
#  ['897', '1.886355694', 'joshi_large'],
#  ['876', '1.817537457', 'joshi_large'],
#  ['860', '1.817537457', 'joshi_large'],
#  ['856', '1.817537114', 'joshi_large'],
#  ['855', '1.869986992', 'joshi_large'],
#  ['852', '1.766756073', 'joshi_large'],
#  ['851', '1.817537054', 'joshi_large'],
#  ['845', '1.766756162', 'joshi_large'],
#  ['838', '1.817537256', 'joshi_large'],
#  ['824', '1.817537457', 'joshi_large'],
#  ['807', '1.766755886', 'joshi_large'],
#  ['802', '1.766755387', 'joshi_large'],
#  ['798', '1.766755849', 'joshi_large'],
#  ['798', '1.766755752', 'joshi_large'],
#  ['793', '1.766755342', 'joshi_large'],
#  ['786', '1.817536809', 'joshi_large'],
#  ['783', '1.766755223', 'joshi_large'],
#  ['772', '1.766755402', 'joshi_large'],
#  ['766', '1.715973862', 'joshi_large'],
#  ['759', '1.766755186', 'joshi_large'],
#  ['753', '1.766755626', 'joshi_large'],
#  ['751', '1.841341764', 'joshi_large'],
#  ['743', '1.766755328', 'joshi_large'],
#  ['731', '1.766755067', 'joshi_large'],
#  ['729', '1.715973973', 'joshi_large'],
#  ['728', '1.715973638', 'joshi_large'],
#  ['724', '1.766755573', 'joshi_large'],
#  ['717', '1.766755402', 'joshi_large'],
#  ['716', '1.715973437', 'joshi_large'],
#  ['714', '1.715973906', 'joshi_large'],
#  ['708', '1.715973616', 'joshi_large'],
#  ['705', '1.715973556', 'joshi_large'],
#  ['704', '1.715973414', 'joshi_large'],
#  ['703', '1.766755059', 'joshi_large'],
#  ['695', '1.715973519', 'joshi_large'],
#  ['695', '1.715973333', 'joshi_large'],
#  ['691', '1.817536309', 'joshi_large'],
#  ['688', '1.715973653', 'joshi_large'],
#  ['685', '1.715973184', 'joshi_large'],
#  ['658', '1.715973414', 'joshi_large'],
#  ['656', '1.66519174', 'joshi_large'],
#  ['654', '1.715973407', 'joshi_large'],
#  ['651', '1.715973146', 'joshi_large'],
#  ['645', '1.71597328', 'joshi_large'],
#  ['643', '1.665191755', 'joshi_large'],
#  ['641', '1.715972938', 'joshi_large'],
#  ['640', '1.715972848', 'joshi_large'],
#  ['638', '1.715973355', 'joshi_large'],
#  ['636', '1.766755', 'joshi_large'],
#  ['628', '1.715973146', 'joshi_large'],
#  ['625', '1.76675427', 'joshi_large'],
#  ['623', '1.715973005', 'joshi_large'],
#  ['622', '1.715973198', 'joshi_large'],
#  ['622', '1.665191293', 'joshi_large'],
#  ['617', '1.665191494', 'joshi_large'],
#  ['617', '1.665191405', 'joshi_large'],
#  ['610', '1.715973489', 'joshi_large'],
#  ['605', '1.665191673', 'joshi_large'],
#  ['603', '1.715972848', 'joshi_large'],
#  ['603', '1.6651913', 'joshi_large'],
#  ['593', '1.665191419', 'joshi_large'],
#  ['592', '1.665191233', 'joshi_large'],
#  ['590', '1.71597299', 'joshi_large'],
#  ['583', '1.665191434', 'joshi_large'],
#  ['581', '1.715972602', 'joshi_large'],
#  ['579', '1.66519136', 'joshi_large'],
#  ['578', '1.665191136', 'joshi_large'],
#  ['576', '1.76675377', 'joshi_large'],
#  ['574', '1.665191479', 'joshi_large'],
#  ['573', '1.665191375', 'joshi_large'],
#  ['571', '1.665190972', 'joshi_large'],
#  ['570', '1.665191196', 'joshi_large'],
#  ['569', '1.665191032', 'joshi_large'],
#  ['567', '1.665191531', 'joshi_large'],
#  ['567', '1.665190995', 'joshi_large'],
#  ['566', '1.665191129', 'joshi_large'],
#  ['565', '1.665191092', 'joshi_large'],
#  ['558', '1.614409611', 'joshi_large'],
#  ['555', '1.665191233', 'joshi_large'],
#  ['548', '1.665190987', 'joshi_large'],
#  ['547', '1.665190943', 'joshi_large'],
#  ['546', '1.665190972', 'joshi_large'],
#  ['546', '1.614409551', 'joshi_large'],
#  ['541', '1.715972841', 'joshi_large'],
#  ['538', '1.665190965', 'joshi_large'],
#  ['521', '1.665190972', 'joshi_large'],
#  ['519', '1.614409648', 'joshi_large'],
#  ['516', '1.665190659', 'joshi_large'],
#  ['516', '1.614409782', 'joshi_large'],
#  ['512', '1.614409178', 'joshi_large'],
#  ['511', '1.614409298', 'joshi_large'],
#  ['510', '1.614409432', 'joshi_large'],
#  ['499', '1.61440932', 'joshi_large'],
#  ['489', '1.614409365', 'joshi_large'],
#  ['488', '1.614409126', 'joshi_large'],
#  ['487', '1.665190585', 'joshi_large'],
#  ['486', '1.614409156', 'joshi_large'],
#  ['482', '1.614409201', 'joshi_large'],
#  ['482', '1.614409037', 'joshi_large'],
#  ['471', '1.614409186', 'joshi_large'],
#  ['471', '1.614409156', 'joshi_large'],
#  ['468', '1.614409581', 'joshi_large'],
#  ['466', '1.665190548', 'joshi_large'],
#  ['463', '1.614409171', 'joshi_large'],
#  ['454', '1.614409037', 'joshi_large'],
#  ['453', '1.614409238', 'joshi_large'],
#  ['452', '1.596008342', 'joshi_large'],
#  ['450', '1.614408873', 'joshi_large'],
#  ['447', '1.614409126', 'joshi_large'],
#  ['439', '1.614408828', 'joshi_large'],
#  ['439', '1.614408731', 'joshi_large'],
#  ['431', '1.665190302', 'joshi_large'],
#  ['422', '1.614408843', 'joshi_large'],
#  ['422', '1.614408612', 'joshi_large'],
#  ['422', '1.596007962', 'joshi_large'],
#  ['420', '1.614408992', 'joshi_large'],
#  ['418', '1.614408955', 'joshi_large'],
#  ['417', '1.614408858', 'joshi_large'],
#  ['415', '1.614408635', 'joshi_large'],
#  ['415', '1.596007999', 'joshi_large'],
#  ['409', '1.614408791', 'joshi_large'],
#  ['407', '1.596008111', 'joshi_large'],
#  ['406', '1.596008155', 'joshi_large'],
#  ['403', '1.614408687', 'joshi_large'],
#  ['402', '1.596007977', 'joshi_large'],
#  ['401', '1.614408769', 'joshi_large'],
#  ['394', '1.596008066', 'joshi_large'],
#  ['391', '1.596007962', 'joshi_large'],
#  ['385', '1.596007805', 'joshi_large'],
#  ['379', '1.596007783', 'joshi_large'],
#  ['372', '1.596007753', 'joshi_large'],
#  ['371', '1.596007776', 'joshi_large'],
#  ['369', '1.596007671', 'joshi_large'],
#  ['368', '1.596007597', 'joshi_large'],
#  ['366', '1.596008044', 'joshi_large'],
#  ['364', '1.614409089', 'joshi_large'],
#  ['363', '1.596007679', 'joshi_large'],
#  ['361', '1.59600785', 'joshi_large'],
#  ['361', '1.596007694', 'joshi_large'],
#  ['357', '1.59600753', 'joshi_large'],
#  ['353', '1.596007477', 'joshi_large'],
#  ['351', '1.596007679', 'joshi_large'],
#  ['347', '1.596007619', 'joshi_large'],
#  ['345', '1.596007604', 'joshi_large'],
#  ['342', '1.596007589', 'joshi_large'],
#  ['341', '1.596007708', 'joshi_large'],
#  ['339', '1.596007485', 'joshi_large'],
#  ['333', '1.59600744', 'joshi_large'],
#  ['332', '1.596007634', 'joshi_large'],
#  ['331', '1.5960075', 'joshi_large'],
#  ['325', '1.596007477', 'joshi_large'],
#  ['323', '1.596007396', 'joshi_large'],
#  ['322', '1.596007589', 'joshi_large'],
#  ['322', '1.596007433', 'joshi_large'],
#  ['322', '1.596007381', 'joshi_large'],
#  ['320', '1.596007545', 'joshi_large'],
#  ['311', '1.59600747', 'joshi_large'],
#  ['311', '1.596007254', 'joshi_large'],
#  ['310', '1.59600747', 'joshi_large'],
#  ['305', '1.59600741', 'joshi_large'],
#  ['304', '1.596007321', 'joshi_large'],
#  ['302', '1.596007328', 'joshi_large'],
#  ['291', '1.596007157', 'joshi_large'],
#  ['286', '1.59600709', 'joshi_large'],
#  ['284', '1.596007165', 'joshi_large'],
#  ['276', '1.596007075', 'joshi_large'],
#  ['259', '1.596006896', 'joshi_large'],
#  ['254', '1.59600671', 'joshi_large'],
#  ['251', '1.59600668', 'joshi_large'],
#  ['250', '1.596006963', 'joshi_large'],
#  ['246', '1.596006725', 'joshi_large'],
#  ['244', '1.596006852', 'joshi_large'],
#  ['244', '1.596006613', 'joshi_large'],
#  ['242', '1.596006613', 'joshi_large'],
#  ['241', '1.596006978', 'joshi_large'],
#  ['241', '1.59600665', 'joshi_large'],
#  ['237', '1.596006703', 'joshi_large'],
#  ['234', '1.596006904', 'joshi_large'],
#  ['234', '1.596006643', 'joshi_large'],
#  ['234', '1.596006546', 'joshi_large'],
#  ['230', '1.596006591', 'joshi_large'],
#  ['227', '1.596006621', 'joshi_large'],
#  ['226', '1.596006524', 'joshi_large'],
#  ['222', '1.596006524', 'joshi_large'],
#  ['222', '1.596006487', 'joshi_large'],
#  ['221', '1.596006494', 'joshi_large'],
#  ['218', '1.596006561', 'joshi_large'],
#  ['213', '1.596006658', 'joshi_large'],
#  ['213', '1.596006643', 'joshi_large'],
#  ['213', '1.596006621', 'joshi_large'],
#  ['210', '1.596006524', 'joshi_large'],
#  ['210', '1.596006472', 'joshi_large'],
#  ['209', '1.596006732', 'joshi_large'],
#  ['208', '1.596006479', 'joshi_large'],
#  ['206', '1.596006457', 'joshi_large'],
#  ['205', '1.596006472', 'joshi_large'],
#  ['199', '1.596006509', 'joshi_large'],
#  ['199', '1.596006345', 'joshi_large'],
#  ['198', '1.596006293', 'joshi_large'],
#  ['197', '1.596006338', 'joshi_large'],
#  ['194', '1.596006658', 'joshi_large'],
#  ['193', '1.5960063', 'joshi_large'],
#  ['192', '1.5960063', 'joshi_large'],
#  ['191', '1.596006412', 'joshi_large'],
#  ['188', '1.596006487', 'joshi_large'],
#  ['188', '1.596006487', 'joshi_large'],
#  ['186', '1.596006442', 'joshi_large'],
#  ['186', '1.59600636', 'joshi_large'],
#  ['180', '1.596006166', 'joshi_large'],
#  ['178', '1.59600633', 'joshi_large'],
#  ['178', '1.596006218', 'joshi_large'],
#  ['178', '1.596006203', 'joshi_large'],
#  ['176', '1.596006233', 'joshi_large'],
#  ['174', '1.596006189', 'joshi_large'],
#  ['173', '1.596006151', 'joshi_large'],
#  ['169', '1.596006077', 'joshi_large'],
#  ['168', '1.596006181', 'joshi_large'],
#  ['167', '1.596006144', 'joshi_large'],
#  ['167', '1.596006136', 'joshi_large'],
#  ['166', '1.596006151', 'joshi_large'],
#  ['166', '1.596006144', 'joshi_large'],
#  ['164', '1.596006025', 'joshi_large'],
#  ['163', '1.596006203', 'joshi_large'],
#  ['162', '1.596006159', 'joshi_large'],
#  ['162', '1.596005995', 'joshi_large'],
#  ['156', '1.596006129', 'joshi_large'],
#  ['155', '1.596006054', 'joshi_large'],
#  ['153', '1.59600601', 'joshi_large'],
#  ['153', '1.596006002', 'joshi_large'],
#  ['152', '1.596005965', 'joshi_large'],
#  ['150', '1.596005905', 'joshi_large'],
#  ['146', '1.596005943', 'joshi_large'],
#  ['145', '1.596005898', 'joshi_large'],
#  ['143', '1.596005883', 'joshi_large'],
#  ['141', '1.596005838', 'joshi_large'],
#  ['140', '1.596006025', 'joshi_large'],
#  ['139', '1.59600592', 'joshi_large'],
#  ['138', '1.59600598', 'joshi_large'],
#  ['130', '1.596005779', 'joshi_large'],
#  ['129', '1.596005727', 'joshi_large'],
#  ['128', '1.596005742', 'joshi_large'],
#  ['124', '1.596005794', 'joshi_large'],
#  ['123', '1.596005704', 'joshi_large'],
#  ['123', '1.596005667', 'joshi_large'],
#  ['118', '1.596005712', 'joshi_large'],
#  ['115', '1.596005645', 'joshi_large'],
#  ['113', '1.596005607', 'joshi_large'],
#  ['111', '1.596005667', 'joshi_large'],
#  ['110', '1.596005585', 'joshi_large'],
#  ['110', '1.596005548', 'joshi_large'],
#  ['108', '1.596005704', 'joshi_large'],
#  ['107', '1.596005674', 'joshi_large'],
#  ['107', '1.59600557', 'joshi_large'],
#  ['99', '1.596005496', 'joshi_large'],
#  ['97', '1.596005511', 'joshi_large'],
#  ['96', '1.596005525', 'joshi_large'],
#  ['96', '1.596005473', 'joshi_large'],
#  ['94', '1.596005503', 'joshi_large'],
#  ['94', '1.596005421', 'joshi_large'],
#  ['93', '1.596005496', 'joshi_large'],
#  ['91', '1.596005548', 'joshi_large'],
#  ['90', '1.596005451', 'joshi_large'],
#  ['87', '1.596005421', 'joshi_large'],
#  ['85', '1.596005391', 'joshi_large'],
#  ['85', '1.596005369', 'joshi_large'],
#  ['83', '1.596005362', 'joshi_large'],
#  ['82', '1.596005421', 'joshi_large'],
#  ['82', '1.596005369', 'joshi_large'],
#  ['81', '1.596005406', 'joshi_large'],
#  ['77', '1.596005362', 'joshi_large'],
#  ['76', '1.596005302', 'joshi_large'],
#  ['74', '1.59600528', 'joshi_large'],
#  ['73', '1.596005272', 'joshi_large'],
#  ['73', '1.596005257', 'joshi_large'],
#  ['73', '1.59600525', 'joshi_large'],
#  ['72', '1.596005242', 'joshi_large'],
#  ['68', '1.596005309', 'joshi_large'],
#  ['67', '1.596005347', 'joshi_large'],
#  ['66', '1.596005227', 'joshi_large'],
#  ['66', '1.596005227', 'joshi_large'],
#  ['62', '1.596005257', 'joshi_large'],
#  ['62', '1.596005205', 'joshi_large'],
#  ['62', '1.596005198', 'joshi_large'],
#  ['61', '1.596005246', 'joshi_large'],
#  ['61', '1.596005175', 'joshi_large'],
#  ['60', '1.59600522', 'joshi_large'],
#  ['58', '1.596005242', 'joshi_large'],
#  ['57', '1.596005183', 'joshi_large'],
#  ['56', '1.596005131', 'joshi_large'],
#  ['54', '1.596005131', 'joshi_large'],
#  ['45', '1.596005071', 'joshi_large'],
#  ['40', '1.596005011', 'joshi_large'],
#  ['35', '1.596004996', 'joshi_large'],
#  ['35', '1.596004974', 'joshi_large'],
#  ['33', '1.596004996', 'joshi_large'],
#  ['33', '1.596004974', 'joshi_large'],
#  ['32', '1.596004974', 'joshi_large'],
#  ['2313', '1.867543221', 'incr_large'],
#  ['2221', '1.846849442', 'incr_large'],
#  ['1924', '1.830630302', 'incr_large'],
#  ['1895', '1.848216534', 'incr_large'],
#  ['1718', '1.874289989', 'incr_large'],
#  ['1649', '1.874979973', 'incr_large'],
#  ['1506', '1.86452961', 'incr_large'],
#  ['1433', '1.928245068', 'incr_large'],
#  ['1297', '1.790079117', 'incr_large'],
#  ['1295', '1.894347191', 'incr_large'],
#  ['1288', '1.782757759', 'incr_large'],
#  ['1281', '1.899464607', 'incr_large'],
#  ['1145', '1.72254467', 'incr_large'],
#  ['1144', '1.812548637', 'incr_large'],
#  ['1125', '1.730449677', 'incr_large'],
#  ['1120', '1.689279079', 'incr_large'],
#  ['1102', '1.658527374', 'incr_large'],
#  ['1092', '1.7899189', 'incr_large'],
#  ['1092', '1.88850975', 'incr_large'],
#  ['1079', '1.824918747', 'incr_large'],
#  ['1077', '1.912472725', 'incr_large'],
#  ['1066', '1.599965096', 'incr_large'],
#  ['1040', '1.831839561', 'incr_large'],
#  ['1019', '1.784448624', 'incr_large'],
#  ['1019', '1.769789696', 'incr_large'],
#  ['1017', '1.913774014', 'incr_large'],
#  ['1014', '1.794266224', 'incr_large'],
#  ['1007', '1.730428219', 'incr_large'],
#  ['1005', '1.714336872', 'incr_large'],
#  ['1003', '1.704360962', 'incr_large'],
#  ['994', '1.708513737', 'incr_large'],
#  ['989', '1.721337318', 'incr_large'],
#  ['988', '1.722279072', 'incr_large'],
#  ['987', '1.795825481', 'incr_large'],
#  ['984', '1.833084106', 'incr_large'],
#  ['978', '1.801989079', 'incr_large'],
#  ['977', '1.731198311', 'incr_large'],
#  ['976', '1.749919415', 'incr_large'],
#  ['964', '1.656320095', 'incr_large'],
#  ['961', '1.806984425', 'incr_large'],
#  ['947', '1.6545434', 'incr_large'],
#  ['945', '1.897893429', 'incr_large'],
#  ['921', '1.830297947', 'incr_large'],
#  ['920', '1.63210392', 'incr_large'],
#  ['905', '1.843821049', 'incr_large'],
#  ['902', '1.755744934', 'incr_large'],
#  ['897', '1.569432735', 'incr_large'],
#  ['876', '1.676368713', 'incr_large'],
#  ['860', '1.622602463', 'incr_large'],
#  ['856', '1.82394743', 'incr_large'],
#  ['855', '1.802253246', 'incr_large'],
#  ['852', '1.675542831', 'incr_large'],
#  ['851', '1.643931389', 'incr_large'],
#  ['845', '1.617748737', 'incr_large'],
#  ['838', '1.702965736', 'incr_large'],
#  ['824', '1.81148243', 'incr_large'],
#  ['807', '1.65664196', 'incr_large'],
#  ['802', '1.621766567', 'incr_large'],
#  ['798', '1.713552952', 'incr_large'],
#  ['798', '1.582796574', 'incr_large'],
#  ['793', '1.629441738', 'incr_large'],
#  ['786', '1.732703209', 'incr_large'],
#  ['783', '1.775829792', 'incr_large'],
#  ['772', '1.668487549', 'incr_large'],
#  ['766', '1.629037857', 'incr_large'],
#  ['759', '1.803453445', 'incr_large'],
#  ['753', '1.621766567', 'incr_large'],
#  ['751', '1.747941017', 'incr_large'],
#  ['743', '1.809115887', 'incr_large'],
#  ['731', '1.830020428', 'incr_large'],
#  ['729', '1.570076466', 'incr_large'],
#  ['728', '1.6323843', 'incr_large'],
#  ['724', '1.719701767', 'incr_large'],
#  ['717', '1.953045368', 'incr_large'],
#  ['716', '1.620334148', 'incr_large'],
#  ['714', '1.591632843', 'incr_large'],
#  ['708', '1.679014206', 'incr_large'],
#  ['705', '1.684230804', 'incr_large'],
#  ['704', '1.879676819', 'incr_large'],
#  ['703', '1.785558701', 'incr_large'],
#  ['695', '1.729171276', 'incr_large'],
#  ['695', '1.671608925', 'incr_large'],
#  ['691', '1.855733871', 'incr_large'],
#  ['688', '1.576837063', 'incr_large'],
#  ['685', '1.709925652', 'incr_large'],
#  ['658', '1.642677307', 'incr_large'],
#  ['656', '1.620005131', 'incr_large'],
#  ['654', '1.558959007', 'incr_large'],
#  ['651', '1.758822441', 'incr_large'],
#  ['645', '1.723223686', 'incr_large'],
#  ['643', '1.622107029', 'incr_large'],
#  ['641', '1.755355835', 'incr_large'],
#  ['640', '1.785458565', 'incr_large'],
#  ['638', '1.833501816', 'incr_large'],
#  ['636', '1.886018276', 'incr_large'],
#  ['628', '1.596335411', 'incr_large'],
#  ['625', '1.987530708', 'incr_large'],
#  ['623', '1.829888821', 'incr_large'],
#  ['622', '1.906032562', 'incr_large'],
#  ['622', '1.637745857', 'incr_large'],
#  ['617', '1.676663876', 'incr_large'],
#  ['617', '1.682988644', 'incr_large'],
#  ['610', '1.7475667', 'incr_large'],
#  ['605', '1.790455818', 'incr_large'],
#  ['603', '1.647088528', 'incr_large'],
#  ['603', '1.800982475', 'incr_large'],
#  ['593', '1.836341858', 'incr_large'],
#  ['592', '1.837692738', 'incr_large'],
#  ['590', '1.81240654', 'incr_large'],
#  ['583', '1.519466877', 'incr_large'],
#  ['581', '1.70900631', 'incr_large'],
#  ['579', '1.805199146', 'incr_large'],
#  ['578', '1.64226675', 'incr_large'],
#  ['576', '1.931475163', 'incr_large'],
#  ['574', '1.547579288', 'incr_large'],
#  ['573', '1.643673897', 'incr_large'],
#  ['571', '1.621857166', 'incr_large'],
#  ['570', '1.696777344', 'incr_large'],
#  ['569', '1.655995369', 'incr_large'],
#  ['567', '1.675610065', 'incr_large'],
#  ['567', '1.534495354', 'incr_large'],
#  ['566', '1.649347305', 'incr_large'],
#  ['565', '1.74074173', 'incr_large'],
#  ['558', '1.632352829', 'incr_large'],
#  ['555', '1.594347954', 'incr_large'],
#  ['548', '1.806460381', 'incr_large'],
#  ['547', '1.79013443', 'incr_large'],
#  ['546', '1.745130539', 'incr_large'],
#  ['546', '1.626704693', 'incr_large'],
#  ['541', '1.753022671', 'incr_large'],
#  ['538', '1.86546278', 'incr_large'],
#  ['521', '1.755393028', 'incr_large'],
#  ['519', '1.73389101', 'incr_large'],
#  ['516', '1.568753242', 'incr_large'],
#  ['516', '1.826458931', 'incr_large'],
#  ['512', '1.71013689', 'incr_large'],
#  ['511', '1.683489323', 'incr_large'],
#  ['510', '1.747437477', 'incr_large'],
#  ['499', '1.746382236', 'incr_large'],
#  ['489', '1.763921261', 'incr_large'],
#  ['488', '1.64087677', 'incr_large'],
#  ['487', '1.762336731', 'incr_large'],
#  ['486', '1.808710575', 'incr_large'],
#  ['482', '1.831413746', 'incr_large'],
#  ['482', '1.621816158', 'incr_large'],
#  ['471', '1.620144367', 'incr_large'],
#  ['471', '1.782235622', 'incr_large'],
#  ['468', '1.751061916', 'incr_large'],
#  ['466', '1.906036377', 'incr_large'],
#  ['463', '1.910749912', 'incr_large'],
#  ['454', '1.940198421', 'incr_large'],
#  ['453', '1.78010273', 'incr_large'],
#  ['452', '1.628340244', 'incr_large'],
#  ['450', '1.711932182', 'incr_large'],
#  ['447', '1.72571373', 'incr_large'],
#  ['439', '1.760479927', 'incr_large'],
#  ['439', '1.721469402', 'incr_large'],
#  ['431', '1.926703453', 'incr_large'],
#  ['422', '1.762485981', 'incr_large'],
#  ['422', '1.593243599', 'incr_large'],
#  ['422', '1.753240108', 'incr_large'],
#  ['420', '1.862487316', 'incr_large'],
#  ['418', '1.831860542', 'incr_large'],
#  ['417', '1.772988319', 'incr_large'],
#  ['415', '1.830384254', 'incr_large'],
#  ['415', '1.616772652', 'incr_large'],
#  ['409', '1.746382236', 'incr_large'],
#  ['407', '1.608218193', 'incr_large'],
#  ['406', '1.732340813', 'incr_large'],
#  ['403', '1.764597893', 'incr_large'],
#  ['402', '1.671232224', 'incr_large'],
#  ['401', '1.78704834', 'incr_large'],
#  ['394', '1.777015686', 'incr_large'],
#  ['391', '1.631875038', 'incr_large'],
#  ['385', '1.598227978', 'incr_large'],
#  ['379', '1.627860546', 'incr_large'],
#  ['372', '1.61600256', 'incr_large'],
#  ['371', '1.582936764', 'incr_large'],
#  ['369', '1.683156967', 'incr_large'],
#  ['368', '1.545829773', 'incr_large'],
#  ['366', '1.787271023', 'incr_large'],
#  ['364', '1.862564564', 'incr_large'],
#  ['363', '1.712803841', 'incr_large'],
#  ['361', '1.7482934', 'incr_large'],
#  ['361', '1.732165337', 'incr_large'],
#  ['357', '1.586246014', 'incr_large'],
#  ['353', '1.598533154', 'incr_large'],
#  ['351', '1.724075317', 'incr_large'],
#  ['347', '1.713291645', 'incr_large'],
#  ['345', '1.752153873', 'incr_large'],
#  ['342', '1.678425312', 'incr_large'],
#  ['341', '1.712983131', 'incr_large'],
#  ['339', '1.53142786', 'incr_large'],
#  ['333', '1.635102272', 'incr_large'],
#  ['332', '1.712637901', 'incr_large'],
#  ['331', '1.560162067', 'incr_large'],
#  ['325', '1.693825722', 'incr_large'],
#  ['323', '1.619114876', 'incr_large'],
#  ['322', '1.568148136', 'incr_large'],
#  ['322', '1.642401695', 'incr_large'],
#  ['322', '1.742385387', 'incr_large'],
#  ['320', '1.710894585', 'incr_large'],
#  ['311', '1.682969093', 'incr_large'],
#  ['311', '1.704240322', 'incr_large'],
#  ['310', '1.740180969', 'incr_large'],
#  ['305', '1.67270565', 'incr_large'],
#  ['304', '1.64975071', 'incr_large'],
#  ['302', '1.715808868', 'incr_large'],
#  ['291', '1.553423405', 'incr_large'],
#  ['286', '1.517983913', 'incr_large'],
#  ['284', '1.647315502', 'incr_large'],
#  ['276', '1.725266457', 'incr_large'],
#  ['259', '1.564211845', 'incr_large'],
#  ['254', '1.521317482', 'incr_large'],
#  ['251', '1.545830727', 'incr_large'],
#  ['250', '1.53965044', 'incr_large'],
#  ['246', '1.564795494', 'incr_large'],
#  ['244', '1.537382603', 'incr_large'],
#  ['244', '1.591531754', 'incr_large'],
#  ['242', '1.554935455', 'incr_large'],
#  ['241', '1.521034718', 'incr_large'],
#  ['241', '1.629257202', 'incr_large'],
#  ['237', '1.589598656', 'incr_large'],
#  ['234', '1.536595345', 'incr_large'],
#  ['234', '1.589193344', 'incr_large'],
#  ['234', '1.668602467', 'incr_large'],
#  ['230', '1.563360691', 'incr_large'],
#  ['227', '1.554497719', 'incr_large'],
#  ['226', '1.532687664', 'incr_large'],
#  ['222', '1.576076508', 'incr_large'],
#  ['222', '1.621939659', 'incr_large'],
#  ['221', '1.475489616', 'incr_large'],
#  ['218', '1.494263649', 'incr_large'],
#  ['213', '1.557235241', 'incr_large'],
#  ['213', '1.617129326', 'incr_large'],
#  ['213', '1.633102894', 'incr_large'],
#  ['210', '1.588999748', 'incr_large'],
#  ['210', '1.576589584', 'incr_large'],
#  ['209', '1.538363934', 'incr_large'],
#  ['208', '1.599863529', 'incr_large'],
#  ['206', '1.580238819', 'incr_large'],
#  ['205', '1.502483845', 'incr_large'],
#  ['199', '1.540676117', 'incr_large'],
#  ['199', '1.591389656', 'incr_large'],
#  ['198', '1.486732483', 'incr_large'],
#  ['197', '1.49461937', 'incr_large'],
#  ['194', '1.580671787', 'incr_large'],
#  ['193', '1.553314209', 'incr_large'],
#  ['192', '1.548752785', 'incr_large'],
#  ['191', '1.518903732', 'incr_large'],
#  ['188', '1.606356144', 'incr_large'],
#  ['188', '1.600193977', 'incr_large'],
#  ['186', '1.565995216', 'incr_large'],
#  ['186', '1.540474892', 'incr_large'],
#  ['180', '1.481217861', 'incr_large'],
#  ['178', '1.502949715', 'incr_large'],
#  ['178', '1.55596447', 'incr_large'],
#  ['178', '1.537510872', 'incr_large'],
#  ['176', '1.579640865', 'incr_large'],
#  ['174', '1.56964016', 'incr_large'],
#  ['173', '1.475922108', 'incr_large'],
#  ['169', '1.529247761', 'incr_large'],
#  ['168', '1.556189537', 'incr_large'],
#  ['167', '1.480238438', 'incr_large'],
#  ['167', '1.491733074', 'incr_large'],
#  ['166', '1.505330086', 'incr_large'],
#  ['166', '1.496960163', 'incr_large'],
#  ['164', '1.475597858', 'incr_large'],
#  ['163', '1.574453354', 'incr_large'],
#  ['162', '1.541214943', 'incr_large'],
#  ['162', '1.517720222', 'incr_large'],
#  ['156', '1.491799831', 'incr_large'],
#  ['155', '1.527109623', 'incr_large'],
#  ['153', '1.508533001', 'incr_large'],
#  ['153', '1.543662548', 'incr_large'],
#  ['152', '1.508505344', 'incr_large'],
#  ['150', '1.488879204', 'incr_large'],
#  ['146', '1.505511761', 'incr_large'],
#  ['145', '1.504061222', 'incr_large'],
#  ['143', '1.532421589', 'incr_large'],
#  ['141', '1.488184929', 'incr_large'],
#  ['140', '1.517505169', 'incr_large'],
#  ['139', '1.469373703', 'incr_large'],
#  ['138', '1.505429268', 'incr_large'],
#  ['130', '1.451192856', 'incr_large'],
#  ['129', '1.450214386', 'incr_large'],
#  ['128', '1.488140106', 'incr_large'],
#  ['124', '1.467245579', 'incr_large'],
#  ['123', '1.463347435', 'incr_large'],
#  ['123', '1.462599754', 'incr_large'],
#  ['118', '1.486540794', 'incr_large'],
#  ['115', '1.49049902', 'incr_large'],
#  ['113', '1.455094337', 'incr_large'],
#  ['111', '1.465717793', 'incr_large'],
#  ['110', '1.458366871', 'incr_large'],
#  ['110', '1.457820415', 'incr_large'],
#  ['108', '1.506486416', 'incr_large'],
#  ['107', '1.442031384', 'incr_large'],
#  ['107', '1.490441322', 'incr_large'],
#  ['99', '1.449997425', 'incr_large'],
#  ['97', '1.470852375', 'incr_large'],
#  ['96', '1.459282398', 'incr_large'],
#  ['96', '1.444017887', 'incr_large'],
#  ['94', '1.450077534', 'incr_large'],
#  ['94', '1.432935238', 'incr_large'],
#  ['93', '1.440741539', 'incr_large'],
#  ['91', '1.474408627', 'incr_large'],
#  ['90', '1.435147285', 'incr_large'],
#  ['87', '1.420624733', 'incr_large'],
#  ['85', '1.442177296', 'incr_large'],
#  ['85', '1.432786942', 'incr_large'],
#  ['83', '1.440736771', 'incr_large'],
#  ['82', '1.465026855', 'incr_large'],
#  ['82', '1.442968369', 'incr_large'],
#  ...]

# %%
def map_color(label):
    if label=="joshi_base":
        return 'b'
    elif label == "joshi_large":
        return 'g'
    elif label == "incr_small":
        return 'y'
    elif label == "incr_large":
        return 'tab:orange'
    else:
        return 'k'
    
def map_marker(label):
    if label=="joshi_base":
        return '1'
    elif label == "joshi_large":
        return '2'
    elif label == "incr_small":
        return '.'
    elif label == "incr_large":
        return '_'
    else:
        return '*'
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "serif"

# %%
models = ["joshi_base", "joshi_large", "incr_small", "incr_large"]
real_name = {"joshi_base": "JS-B",
             "joshi_large": "JS-L",
             "incr_small": "Ours (128)",
             "incr_large": "Ours (512)",           
            }
sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
fig, ax = plt.subplots()
fig.set_size_inches(4.5,3)
for model in models:
    model_data = [d for d in data if d[2] == model]
    for i, d in enumerate(model_data):
        plt.scatter(int(d[0]), float(d[1]), 
                    color=map_color(model), 
                    alpha=0.5,
                    marker=map_marker(model),
                    s = 100,
                    label=real_name[model] if i==0 else "")
plt.xlim(0, 2500);
plt.ylim(0, 5);
# plt.grid(False)
# plt.grid(b=True, which="major")
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12)
# ax.set_facecolor('white')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

plt.legend(loc="upper left", fontsize=10)
plt.xlabel('Document Length (Tokens)', fontsize=12)
plt.ylabel('Peak Memory (GB)', fontsize=12)
plt.savefig('memory.svg')
